# '\n###### Exercise 1\nQ1_p = 2259347842534800385466908184705005746923366955823231161456221450510974272279565006803387081465187439697947\nQ1_r = 1318843402067846217646746067621904383\nQ1_h = 2\nQ1_g1 = 2133981808743710084201413644935081987999357430281845929655848184284387230647623566018151023481476965231039\nQ1_g2 = 838899224832541053272597682998472644855639813145691755624681071651406524738674795898848269083531932715893\nQ1_g1x1 = 1246171561856210105406728063262496165159802596129467313293881907013387981873230403217208198067349619714758\nQ1_g2x1 = 2039293299614674401774785943412648667809151419573259031199057685574723137529658217728023859347025450601008\nQ1_g1z1 = 1052830611956341653464627931239069590936872341617364565434532850929062201250444089942547991057512157950153\nQ1_g2z1 = 1786012283023414093260344229948527551205053448278393105343768338886522300376497669623773283941632739601673\nQ1_g1x2 = 21339818087437100842014136449350819879993574302818459296558481842843872306476235660181510234
# ...

# %% [markdown]
# ## Finding i s.t. i^2 + 1 = 0 and Mapping e to ê

# %% [markdown]
# Ellipitic curves in Sage defined as \\(y^2+a_1xy+a_3y=x^3+a_2x^2+a_4x+a_6\\), we want an elliptic curve of the form \\(y^2=x^3+x\\)

# %%
g = (Q1_g1, Q1_g2)

# %%
E = EllipticCurve(GF(Q1_p), [1, 0]) # [a4,a6] = [1,0] 
R.<x> = GF(Q1_p)[]
K.<a> = GF(Q1_p ^ Q1_h, modulus = x ^ 2 + 1)    #Q1_h = 2
EK = E.base_extend(K)

# %%
EK(0, 0)
# Out:
# (0 : 0 : 1)

# %%
def phi(h):
    return EK(-h[0], a * h[1])

# %%
def e(g, h):
    P = EK(g[0], g[1])
    Q = EK(h[0],h[1])
    return P.tate_pairing(Q, P.order(), Q1_h)

# %%
e(g,g)
# Out:
# 1

# %%
def chapo(g, h):
    return e(g, phi(h))

# %%
chapo(g,g)
# Out:
# 1922463550071734721240252668431323630478844887618227515122969008989383691751396754830966719616037149406841*a + 868764872924267874691688740442354012713076430443742688928783456530859682208357471885549906950517489884903

# %% [markdown]
# ## SDH Pairs

# %% [markdown]
# Your first task is to determine the maximal subset J where ∅ ⊂ J ⊆ I such that each value (gxj , gzj ) is a valid SDH pair. Record your answer in Q1_J as an array of integers, i.e. in the form Q1_J = [500, 501, 4957, 26666].

# %% [markdown]
# We say that (\\(g^{x_i} , g^{z_i} \\)) is a valid Strong Diffie-Hellman pair (or valid SDH pair) if and only if \\(g^{x^2_i} = g^{z_i}\\).

# %% [markdown]
# Pairs are of the form: ((Q1_g1xi, Q1_g2xi), (Q1_g1zi, Q1_g2zi))

# %%
allPairs = [((Q1_g1x1, Q1_g2x1), (Q1_g1z1, Q1_g2z1)), 
            ((Q1_g1x2, Q1_g2x2), (Q1_g1z2, Q1_g2z2)), 
            ((Q1_g1x3, Q1_g2x3), (Q1_g1z3, Q1_g2z3)), 
            ((Q1_g1x4, Q1_g2x4), (Q1_g1z4, Q1_g2z4)),
            ((Q1_g1x5, Q1_g2x5), (Q1_g1z5, Q1_g2z5)),
            ((Q1_g1x6, Q1_g2x6), (Q1_g1z6, Q1_g2z6)),
            ((Q1_g1x7, Q1_g2x7), (Q1_g1z7, Q1_g2z7)),
            ((Q1_g1x8, Q1_g2x8), (Q1_g1z8, Q1_g2z8)),
            ((Q1_g1x9, Q1_g2x9), (Q1_g1z9, Q1_g2z9)),
            ((Q1_g1x10, Q1_g2x10), (Q1_g1z10, Q1_g2z10)),
            ((Q1_g1x11, Q1_g2x11), (Q1_g1z11, Q1_g2z11)),
            ((Q1_g1x12, Q1_g2x12), (Q1_g1z12, Q1_g2z12)),
            ((Q1_g1x13, Q1_g2x13), (Q1_g1z13, Q1_g2z13)),
            ((Q1_g1x14, Q1_g2x14), (Q1_g1z14, Q1_g2z14)),
            ((Q1_g1x15, Q1_g2x15), (Q1_g1z15, Q1_g2z15)),
            ((Q1_g1x16, Q1_g2x16), (Q1_g1z16, Q1_g2z16)),
            ((Q1_g1x17, Q1_g2x17), (Q1_g1z17, Q1_g2z17)),
            ((Q1_g1x18, Q1_g2x18), (Q1_g1z18, Q1_g2z18)),
            ((Q1_g1x19, Q1_g2x19), (Q1_g1z19, Q1_g2z19)),
            ((Q1_g1x20, Q1_g2x20), (Q1_g1z20, Q1_g2z20)),
            ((Q1_g1x21, Q1_g2x21), (Q1_g1z21, Q1_g2z21)),
            ((Q1_g1x22, Q1_g2x22), (Q1_g1z22, Q1_g2z22)),
            ((Q1_g1x23, Q1_g2x23), (Q1_g1z23, Q1_g2z23)),
            ((Q1_g1x24, Q1_g2x24), (Q1_g1z24, Q1_g2z24))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-018379be3089> in <module>
#      19             ((Q1_g1x19, Q1_g2x19), (Q1_g1z19, Q1_g2z19)),
#      20             ((Q1_g1x20, Q1_g2x20), (Q1_g1z20, Q1_g2z20)),
# ---> 21             ((Q1_g1x21, Q1_g2x21), (Q1_g1z21, Q1_g2z21)),
#      22             ((Q1_g1x22, Q1_g2x22), (Q1_g1z22, Q1_g2z22)),
#      23             ((Q1_g1x23, Q1_g2x23), (Q1_g1z23, Q1_g2z23)),
#
# NameError: name 'Q1_g1x21' is not defined

# %%
def checkIfSDH(pair):
    return chapo(pair[0], pair[0]) == chapo(pair[1], g)

# %%
def checkAll(pairs):
    validSDHPairs = []
    for pair in pairs:
        if(checkIfSDH(pair)):
            validSDHPairs.append(pair)
    return validSDHPairs

# %%
answer = checkAll(allPairs)

# %%
len(answer)

# %% [markdown]
# ## Recover the j-invariant inv of E

# %% [markdown]
# Our cryptographic student noticed that there are many different curves that are specified in practice for use. The student devised this challenge to determine what kind of information might suffice to represent an elliptic curve.

# %% [markdown]
# Let \\(E : y^2 = x^3 + Ax + B \\) be an elliptic curve defined over a field \\(F_q\\), where \\(q\\) is given in Q1_q as an integer. You are given that the points \\(S = {(x,y),(x + 1,y),(x + 2,y)} \\) lie on E for some x and y, and that \\((x_0,y_0)\\) lies on E, which is stored as Q1_x0, Q1_y0 in integer format.

# %% [markdown]
# https://doc.sagemath.org/html/en/reference/polynomial_rings/sage/rings/polynomial/multi_polynomial_ideal.html

# %% [markdown]
# https://ask.sagemath.org/question/30536/solving-simultaneous-equations/

# %% [markdown]
# ### Method 1 : Groebner

# %%
# Manon Parameters (work for this method)
Q1_q = 
Q1_x0 = 
Q1_y0 = 

# %%
#x, y, a, b = polygens(QQ,'x,y,a,b')
A.<x,y,a,b> = Zmod(Q1_q)[]
eq1 = y^2 - x^3 - a*x - b
eq2 = y^2 - (x+1)^3 - a*(x+1) - b
eq3 = y^2 - (x+2)^3 - a*(x+2) - b
eq4 = Q1_y0^2 - Q1_x0^3 - a*Q1_x0 - b

# %%
I = A.ideal([eq1,eq2,eq3,eq4])
#B = I.groebner_basis()

# %%
grob_sols = I.variety()
grob_sols
# Out:
# verbose 0 (3837: multi_polynomial_ideal.py, groebner_basis) Warning: falling back to very slow toy implementation.
# verbose 0 (1080: multi_polynomial_ideal.py, dimension) Warning: falling back to very slow toy implementation.
# verbose 0 (2270: multi_polynomial_ideal.py, variety) Warning: falling back to very slow toy implementation.
# verbose 0 (3837: multi_polynomial_ideal.py, groebner_basis) Warning: falling back to very slow toy implementation.
# verbose 0 (3837: multi_polynomial_ideal.py, groebner_basis) Warning: falling back to very slow toy implementation.
# verbose 0 (3837: multi_polynomial_ideal.py, groebner_basis) Warning: falling back to very slow toy implementation.
# []

# %%
groba = grob_sols[0][a]
grobb = grob_sols[0][b]

# %% [markdown]
# #### Test

# %%
def test_sol(sol):
    x3 = power_mod(sol[x],3,Q1_q)
    ax = Mod(sol[x]*sol[a], Q1_q)
    y2 = power_mod(sol[y],2,Q1_q)
    
    assert(y2 == Mod(x3 + ax + sol[b], Q1_q))
    
    x13 = power_mod(sol[x]+1,3,Q1_q)
    a1x = Mod((sol[x]+1)*sol[a], Q1_q)
    assert(y2 == Mod(x13 + a1x + sol[b], Q1_q))
    
    x23 = power_mod(sol[x]+2,3,Q1_q)
    a2x = Mod((sol[x]+2)*sol[a], Q1_q)
    assert(y2 == Mod(x23 + a2x + sol[b], Q1_q))
    
    assert(power_mod(Q1_y0,2,Q1_q) == Mod(power_mod(Q1_x0,3,Q1_q) + Mod(Q1_x0*sol[a], Q1_q) + sol[b], Q1_q))

# %%
for sol in grob_sols:
    test_sol(sol)

# %% [markdown]
# ### Method 2: solve

# %%
a, b = var('a, b')
x, y = var('x, y')
eqs = [y**2 == x**3 + a * x + b, y**2 == (x+1)**3 + a * (x+1) + b, y**2 == (x+2)**3 + a * (x+2) + b, Q1_y0**2 == Q1_x0**3 + a * Q1_x0 + b]

res=solve(eqs,a,b,x,y, solution_dict=True, explicit_solutions=True)

# %%
res
# Out:
# [{a: -1,
#   b: -...,
#   x: -1,
#   y: -I*sqrt(...)},
#  {a: -1,
#   b: -...,
#   x: -1,
#   y: I*sqrt(...)}]

# %%
for sol in res:

    sola = int(sol[a])
    solb = int(sol[b])
   
    
    assert(power_mod(Q1_y0,2,Q1_q) == Mod(power_mod(Q1_x0,3,Q1_q) + Mod(Q1_x0*sola, Q1_q) + solb, Q1_q))

# %%
sola, solb
# Out:
# (-1,
#  -...)

# %%
modsola=Mod(sola, Q1_q)
modsolb=Mod(solb, Q1_q)

# %% [markdown]
# ### j-invariant

# %% [markdown]
#  j-invariant: \\(j = 1728\frac{4a^3}{4a^3 + 27b^2} \\)

# %%
def j_invariant(a,b):
    part_a = 4*(a^3)
    part_b = (4*(a^3))+(27*(b^2))
    j_inv = 1278*(part_a/part_b)
    return j_inv, part_a, part_b

# %%
j, pa, pb = j_invariant(sola,modsolb)
j, pa, pb
# Out:
# (,
#  -4,
#  )

# %%
gcd_ab = gcd(pa,pb)

# %%
final_a = pa/gcd_ab
final_b = pb/gcd_ab

# %%
final_a, final_b
# Out:
# (,
#  )
